# %% [markdown]
# ## Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np
#for 3d graph
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map
import math

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

#to import sympy
from sympy import symbols, diff

# %matplotlib inline

# %% [markdown]
# ### Example 1 - A simple cost function
#
# $f(x) = x^2 + x + 1$

# %%
def f(x):
    return x**2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# plot
plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1))
plt.show()

# %%
#Find lowest cost
#Stopped at video: "Understanding the Power Rule& Creating Charts with Subplots"

# %% [markdown]
# ## Slope & Derivatives

# %% [markdown]
# Challenge: Create a python function for the derivative of f(x) called df(x)

# %%
def df(x):
    return 2*x + 1

# %% [markdown]
# Finding derivative: "Video (Understanding the power rule & creating..."
# Explanation at 4:00 min

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
# plot function and derivative side by side
#sizing
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
#subplot - using 2 graphs
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Python Loops & Gradient Descent

# %%
# Python For Loop
for n in range(5):
    print('Hello world', n)
print('End of loop')
# Out:
# Hello world 0
# Hello world 1
# Hello world 2
# Hello world 3
# Hello world 4
# End of loop

# %%
# Python while loop
counter = 0
while counter < 7:
    print('Counting..', counter)
    counter += 1
# Out:
# Counting.. 0
# Counting.. 1
# Counting.. 2
# Counting.. 3
# Counting.. 4
# Counting.. 5
# Counting.. 6

# %%
# Gradient Descent
new_x = 3 #change this as the starting point of the descent
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient
    
    step_size = abs(new_x - previous_x)
    # print(step_size)
    
    #basis for plottig our chart
    x_list.append(new_x)
    slope_list.append(df(new_x))
    
    if step_size < precision:
        print('Loop ran this many times:', n)
        break
    
print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: -0.49996003706460423
# Slope or df(x) value at this point is: 7.992587079153068e-05
# f(x) value or cost at this point is: 0.7500000015970362

# %%
# Superimpose the gradient descent calculation on plot
#sizing
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
#subplot - using 2 graphs
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

# scatter only works with array list and not just list values
values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)


# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.32, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
# Make some data
x_2 = np.linspace(-2, 2, 1000)

# Challenge: Write the g(x) function and the dg(x) function in Python
def g(x):
    return x**4 - 4*x**2 + 5
def dg(x):
    return 4*x**3 - 8*x

# %%
# plot function and derivative side by side
#sizing
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
#subplot - using 2 graphs
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent as a Python Function

# %%
def gradient_descent(derivative_func, 
                     initial_guess, 
                     multiplier=0.02, 
                     precision=0.001,
                     max_iter=300):
    
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        # print(step_size)

        #basis for plottig our chart
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break 
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min: ', local_min)
print('Number of steps: ', len(list_x))
# Out:
# Local min:  1.4122375085019094
# Number of steps:  23

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, 
                                                 initial_guess=-0.5, 
                                                 multiplier=0.01, 
                                                 precision=0.0001)
print('Local min: ', local_min)
print('Number of steps: ', len(list_x))
# Out:
# Local min:  -1.4137636556157256
# Number of steps:  56

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, 
                                                 initial_guess=-0.1)
print('Local min: ', local_min)
print('Number of steps: ', len(list_x))
# Out:
# Local min:  -1.4120887490901561
# Number of steps:  34

# %%
# Calling gradient descent 
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, 
                                                 initial_guess=-0.2,
                                                 max_iter=10)
# Plot function and derivative and scatter plot side by side
#sizing
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
#subplot - using 2 graphs
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.8)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence, Overflow and Python Tuples
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
# Make data
x_3 = np.linspace(start=-2.5, stop=2.5, num=1000)

def h(x):
    return x**5 - 2*x**4 + 2

def dh(x):
    return 5*x**4 - 8*x**3

# %%
# Calling gradient descent 
local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, 
                                                 initial_guess=-0.2,
                                                 max_iter=71)
# Plot function and derivative and scatter plot side by side
#sizing
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
#subplot - using 2 graphs
plt.subplot(1, 2, 1)

plt.xlim(-1.2, 2.5)
plt.ylim(-1, 4)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('h(x)', fontsize=16)

plt.plot(x_3, h(x_3), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, h(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dh(x)', fontsize=16)
plt.grid()
plt.xlim(-1, 2)
plt.ylim(-4, 5)

plt.plot(x_3, dh(x_3), color='skyblue', linewidth=5, alpha=0.8)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Local min occurs at: ', local_min)
print('Cost at min is:', h(local_min))
print('Number of steps: ', len(list_x))
# Out:
# Local min occurs at:  -1.8398461123332792e+24
# Cost at min is: -2.1081790694225687e+121
# Number of steps:  72

# %%
# get 
import sys
# help(sys)
# sys.version
type(h(local_min))
sys.float_info.max
# Out:
# 1.7976931348623157e+308

# %% [markdown]
# # Python Tuples

# %%
#tuples - sequence of values seperated by a comma
# Creating a tuple - tuple packing
breakfast = 'bacon', 'eggs', 'avocado'
unlucky_numbers = 13, 4, 9 ,26, 17

# How to accessa value in a tuple
print('I loovee', breakfast[1])
print('My hotel has no ' + str(unlucky_numbers[1]) + 'th floor')

# tuples are different lists as its a mix of data unlike lists
# tuples are IMMUTABLE - unable to change after set
not_my_address = 1, 'Infinite Loop', 'Cupertino', 95014
print('Check', not_my_address[0])

#To be a tuple, needs a comma
tuple_with_single_value = 42, 
print(tuple_with_single_value)
type(tuple_with_single_value)

# sequence unpacking for tuples
main, side, greens = breakfast
print('Main course is', main)

data_tuple = gradient_descent(derivative_func=dh, initial_guess=0.2)
print('Local min is', data_tuple[0])
print('Cost at the last x value is', h(data_tuple[0]))
print('Number of steps is', len(data_tuple[1]))
# Out:
# I loovee eggs
# My hotel has no 4th floor
# Check 1
# (42,)
# Main course is bacon
# Local min is 1.5989534547394717
# Cost at the last x value is -0.6214287992331258
# Number of steps is 117

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent 
# multipler increases step size 
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, 
                                                 initial_guess=1.9,
                                                 multiplier=0.02,
                                                max_iter=500)
# Plot function and derivative and scatter plot side by side
#sizing
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
#subplot - using 2 graphs
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.8)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is:', len(list_x))
# Out:
# Number of steps is: 14

# %%
# Run gradiaten descent 3 times
# multipler increases step size 
n = 100
low_gamma = local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, 
                                                 initial_guess=3,
                                                 multiplier=0.0005,
                                                 precision=0.0001,
                                                max_iter=n)

mid_gamma = local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, 
                                                 initial_guess=3,
                                                 multiplier=0.001,
                                                 precision=0.0001,
                                                max_iter=n)

high_gamma = local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, 
                                                 initial_guess=3,
                                                 multiplier=0.002,
                                                 precision=0.0001,
                                                max_iter=n)

# Experiment - bad example 
insane_gamma = local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, 
                                                 initial_guess=1.9,
                                                 multiplier=0.25,
                                                 precision=0.0001,
                                                max_iter=n) 

# Plotting reduction in cost for each iteration
#sizing
plt.figure(figsize=[20, 10])

plt.xlim(0, n)
plt.ylim(0, 50)
plt.title('Effect of the learning rate', fontsize=17)
plt.xlabel('Number iterations', fontsize=16)
plt.ylabel('Cost', fontsize=16)

# Values for our charts
# 1) Y Axis Data: convert the lists to numpy arrays
low_values = np.array(low_gamma[1])
mid_values = np.array(mid_gamma[1])
high_values = np.array(high_gamma[1])
insane_values = np.array(insane_gamma[1])

# 2) X Axis Data: create a list from 0 to n+1
iteration_list = list(range(0, n+1))

# Plotting Low Learning Rate
#plt.subplot(1, 3, 1)
plt.plot(iteration_list, g(low_values), color='lightgreen', linewidth=5)
plt.scatter(iteration_list, g(low_values), color='lightgreen', s=80)

# Plotting Mid Learning Rate
#plt.subplot(2, 3, 2)
plt.plot(iteration_list, g(mid_values), color='lightblue', linewidth=5)
plt.scatter(iteration_list, g(mid_values), color='lightblue', s=80)

# Plotting Mid Learning Rate
#plt.subplot(3, 3, 3)
plt.plot(iteration_list, g(high_values), color='pink', linewidth=5)
plt.scatter(iteration_list, g(high_values), color='pink', s=80)

# Plotting High Learning Rate
#plt.subplot(3, 3, 3)
plt.plot(iteration_list, g(high_values), color='pink', linewidth=5)
plt.scatter(iteration_list, g(high_values), color='pink', s=80)

# Plotting INSANE Learning Rate
#plt.subplot(3, 3, 3)
plt.plot(iteration_list, g(insane_values), color='red', linewidth=5)
plt.scatter(iteration_list, g(insane_values), color='red', s=80)

plt.show()

# Shows high learning rate converges the fastest - higher the multiplier, the 
# faster the convergence -- but sometimes not always (like the overflow)

# %% [markdown]
# NOTES:
# Bold Driver:
# - If error rate (cost) was reduced, try increase learning rate by 5%
# - If error rate increases (cost) - reset valus of previous iteration, then decrease learning rate by 50%
# RULE:
# - Error rate (COST) DECREASE: increase 5%
# - Error rate (COST) INCREASE: decrease 50%

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
def f(x, y):
    r = 3**(-x**2 - y**2)
    return 1 / (r+1)

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

# to make 2 dimensional 
x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
# Generating 3D Plot - from "mpl_toolkits.mplot3d.axes3d import Axes3D"
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection='3d')

# Set labels of graph 
ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x_y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)



plt.show()

# %% [markdown]
# - Calculate the slope or gradient on diff - steeper the gradient, further away we were, which means higher the cost
# - Just because we have a low y, doesn't mean the cost (x) is low
# - Need to calculate the slope - need to calculate partial derivative (which means calculating based off of either x or y, and the other is held constant)

# %% [markdown]
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = \frac{2x \ln(3) \cdot 3^{-x^2 - y^2}}{\left(3^{-x^2 - y^2} + 1\right)^2}$$
#
# ## $$\frac{\partial f}{\partial y} = \frac{2y \ln(3) \cdot 3^{-x^2 - y^2}}{\left(3^{-x^2 - y^2} + 1\right)^2}$$

# %% [markdown]
# https://www.symbolab.com/solver/derivative-calculator
# Check out documentation in https://www.sympy.org/en/index.html

# %%
#instead of x and y using a and b
a, b = symbols('x, y')
print('Our cost function f(x, y) is: ', f(a, b))
print('Partial derivative with respect to x is: ', diff(f(a, b), a))

#cost at a particular point (from above)
print('Value of f(x,y) at x=1.8, y=1.0 is: ', 
      f(a, b).evalf(subs={a:1.8, b:1.0})) # python dictionary - key value pair

#Challenge - value with respect to 
print('Value of partial derivative with respect to x: ',
      diff(f(a, b), a).evalf(subs={a:1.8, b:1.0}))

plt.show()
# Out:
# Our cost function f(x, y) is:  1/(3**(-x**2 - y**2) + 1)
# Partial derivative with respect to x is:  2*3**(-x**2 - y**2)*x*log(3)/(3**(-x**2 - y**2) + 1)**2
# Value of f(x,y) at x=1.8, y=1.0 is:  0.990604794032582
# Value of partial derivative with respect to x:  0.0368089716197505

# %% [markdown]
# # Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    #working out the slope
    # differentiating with respect to a - evaluating slow at points params[0] and params[1]
    gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    #work with numpy arrays
    gradients = np.array([gradient_x, gradient_y]) #calculating cost based on steepness of slope
    params = params - multiplier * gradients
    
# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('Cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [2.01013037525579e-11 1.11673909736433e-11]
# Minimum occurs at x value of:  3.45838599885832e-11
# Minimum occurs at y value of:  1.92132555492129e-11
# Cost is:  0.500000000000000

# %%
# Challenge
a, b = symbols('x, y')
fpx = (2*a * math.log(3) * 3**(-a**2 - b**2)) / (3**(-a**2 - b**2) + 1)**2
fpy =(2*b * math.log(3) * 3**(-a**2 - b**2)) / (3**(-a**2 - b**2) + 1)**2

# %%
# Challenge - Solution
def fpx(x, y):
    r = 3**(-x**2 - y**2)
    return 2*x*math.log(3)*r / (r + 1)**2

def fpy(x, y):
    r = 3**(-x**2 - y**2)
    return 2*y*math.log(3)*r / (r + 1)**2

# %%
fpx(1.8, 1.0)
# Out:
# 0.036808971619750504

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    #working out the slope
    # differentiating with respect to a - evaluating slow at points params[0] and params[1]
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    #work with numpy arrays
    gradients = np.array([gradient_x, gradient_y]) #calculating cost based on steepness of slope
    params = params - multiplier * gradients
    
# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('Cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [2.01013038e-11 1.11673910e-11]
# Minimum occurs at x value of:  3.458385998858304e-11
# Minimum occurs at y value of:  1.9213255549212797e-11
# Cost is:  0.5

# %% [markdown]
# ## Graphing 3D Gradient Descent & Adv Numpy Arrays

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess
#all valus we track
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    #working out the slope
    # differentiating with respect to a - evaluating slow at points params[0] and params[1]
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    #work with numpy arrays
    gradients = np.array([gradient_x, gradient_y]) #calculating cost based on steepness of slope
    params = params - multiplier * gradients
    # values_array = np.append(values_array, params.reshape(1, 2), axis=0)
#instead of np.append - can concatenate (same as above)
    values_array = np.concatenate((values_array,  params.reshape(1, 2)), axis=0)
    
    
# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('Cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [2.01013038e-11 1.11673910e-11]
# Minimum occurs at x value of:  3.458385998858304e-11
# Minimum occurs at y value of:  1.9213255549212797e-11
# Cost is:  0.5

# %%
# Generating 3D Plot - from "mpl_toolkits.mplot3d.axes3d import Axes3D"
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection='3d')

# Set labels of graph 
ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x_y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1], f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()
# Final plotting of gradient descent

# %%
# Advanced Numpy Array Practice:

kirk = np.array([['Captain', 'Guitar']])
print(kirk.shape)

hs_band = np.array([['Black Thought', 'MC'], ['QuestLove', 'Drums']])
print(hs_band.shape)

print('hs_band[0]', hs_band[0])
print('hs_band[0][1]', hs_band[0][1])

print(hs_band[1][0])

# append takes 3 arguments, array, axis means should we add value as a row or column?
# axis=0 means to add as a row - if axis=1, then items would be added as a column - but it HAS to be the same dimensions
#  as in example 2
the_roots = np.append(arr=hs_band, values=kirk, axis=0)
print(the_roots)
# Example 2
# the_roots = np.append(arr=hs_band, values=kirk.reshape(2,1), axis=1)
# print(the_roots)

# : - means selecting all in the rows (0 is the first column)
print('Printing nickanmes...', the_roots[:, 0])

the_roots = np.append(arr=the_roots, values=[['Malik B', 'MC']], axis=0)
print('Printing band roles....', the_roots[:, 1])
# Out:
# (1, 2)
# (2, 2)
# hs_band[0] ['Black Thought' 'MC']
# hs_band[0][1] MC
# QuestLove
# [['Black Thought' 'MC']
#  ['QuestLove' 'Drums']
#  ['Captain' 'Guitar']]
# Printing nickanmes... ['Black Thought' 'QuestLove' 'Captain']
# Printing band roles.... ['MC' 'Drums' 'Guitar' 'MC']

# %% [markdown]
# # Example 5: Working with Data & a Real Cost Function
# ## Mean Squared Error: a cost function for regression problems
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2$$
# ### $$MSE = \frac{1}{n}\sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2$$
# ### $$MSE = \frac{1}{n}\sum_{i=1}^{n} \big( y - \hat{y} \big)^2$$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.1, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regression
regr = LinearRegression()
regr.fit(x_5, y_5)
#describes best fit line
print('Theta 0:', regr.intercept_[0]) #intercept 
print('Theta 1:', regr.coef_[0][0]) #slope value
# Out:
# Theta 0: 0.8931468961278419
# Theta 1: 1.2141979102642901

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %% [markdown]
# - cost functions are not based off of x, y - will be different, just easier to explain

# %%
# y_hat = theat0 + theta1*x
y_hat = 0.8931468961278419 + 1.2141979102642901 * x_5
print('Estimated values y_hat are:\n', y_hat)
print('In comparison, the actual y values are:\n', y_5)
# Out:
# Estimated values y_hat are:
#  [[1.01456669]
#  [2.2287646 ]
#  [3.80722188]
#  [4.77858021]
#  [5.87135833]
#  [7.81407498]
#  [8.78543331]]
# In comparison, the actual y values are:
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE?  Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
result = mse(y_5, y_hat)
print('Manually calculated MSE is:', result)
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.95243437]
# MSE regression using manual calc is 0.9524343664939858
# MSE regression is 0.9524343664939858

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
# we're plotting a surface - using meshgrid
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

#calculating mean squared error in the range

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas)) # 2d array of just 0

for i in range(nr_thetas):
    for j in range(nr_thetas):
        # print(plot_t0[i][j])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)
        
print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Nested Loop Practice
for i in range(3):
    for j in range(3):
        print(f'value of i is {i} and j is {j}')
# Out:
# value of i is 0 and j is 0
# value of i is 0 and j is 1
# value of i is 0 and j is 2
# value of i is 1 and j is 0
# value of i is 1 and j is 1
# value of i is 1 and j is 2
# value of i is 2 and j is 0
# value of i is 2 and j is 1
# value of i is 2 and j is 2

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection = '3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
# will print out indicies from our 2d array where MSE is at its lowest
ij_min = np.unravel_index(indices=plot_cost.argmin(), shape=plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[110, 95]', plot_t0[110][95])
print('Min MSE for Theta 0 at plot_t1[110, 95]', plot_t1[110][95])
# Out:
# Min value of plot_cost 0.9525166391902085
# Min occurs at (i,j): (110, 95)
# Min MSE for Theta 0 at plot_t0[110, 95] 0.9095477386934674
# Min MSE for Theta 0 at plot_t1[110, 95] 1.2110552763819098

# %% [markdown]
# ## Partial Derivative of MSE w.r.t. $\theta_0$ and $\theta_1$
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big(x^{(i)}\big)$$
#
# - NOTE: partial derivatives will depend on what kind of equation we're using for y_hat
# - here, we're using linear regression with 1 variable - we sub and derive partial derivaties from that
# - if we had a different model, like linear regression w/ 2 variables, or something that estimates y_differently - then we would substitue that for our MSE

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size
    
    #challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivatives
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)
    
    # return np.array([theta0_slope[0], theta1_slope[0]])
    # return np.append(arr=theta0_slope, values=theta1_slope) #appending to theta0_slope
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# plotting values - for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1] * x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)
    
    #append new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1,2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1] * x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8982057950579772
# Min occurs at Theta 1: 1.213103380756207
# MSE is: [0.95244203]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection = '3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
